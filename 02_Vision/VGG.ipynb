# %% [markdown]
# #VGG

# %% [markdown]
# ## 0. Paper

# %% [markdown]
# ### Info
# * Title: Very Deep Convolutional Networks for Large-Scale Image Recognition
# * Author: Karen Simonyan
# * Task: Image Classification
# * Link: https://arxiv.org/abs/1409.1556v6
#
#
# ### Features
# * Dataset: CIFAR-10
# * with Batch normalization
# * Flatten -> AvgPool
#
# ### Reference
# * https://github.com/kuangliu/pytorch-cifar

# %% [markdown]
# ## 1. Setting

# %%
# Libraries
import os
import sys
import time
from glob import glob

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchsummary import torchsummary

# %%
CONFIG = {
    'lr': 0.1,
    'momentum': 0.9,
    'weight_decay': 5e-4,
    'batch_size': 128,
    'epoch_size': 200,
    'base_dir': '/content/drive/Shared drives/Yoon/Project/Doing/Deep Learning Paper Implementation',
}

# %% [markdown]
# ## 2. Data

# %%
def create_dataset():
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2439, 0.2616)),
    ])

    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2439, 0.2616)),
    ])

    train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
    test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
    train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [45000, 5000])
    return train_dataset, val_dataset, test_dataset


def create_dataloader(batch_size):
    train_dataset, val_dataset, test_dataset = create_dataset()
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, val_loader, test_loader

# %%
train_loader, val_loader, test_loader = create_dataloader(CONFIG['batch_size'])
inputs, targets = next(iter(train_loader))
inputs.size(), targets.size()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (torch.Size([128, 3, 32, 32]), torch.Size([128]))

# %% [markdown]
# ## 3. Model

# %%
class Block(nn.Module):
    def __init__(self, in_C, out_C):
        super(Block, self).__init__()
        self.conv = nn.Conv2d(in_C, out_C, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(out_C)
        self.relu = nn.ReLU(inplace=True)
    
    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))

class VGG(nn.Module):
    def __init__(self, cfg, num_classes=10):
        super(VGG, self).__init__()
        self.features = self._make_layer(cfg)
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(self.in_C, num_classes)
        )
        
    def _make_layer(self, cfg):
        layers = []
        self.in_C = 3

        for c in cfg:
            if c == 'M':
                layers.append(nn.MaxPool2d(2))
            else:
                layers.append(Block(self.in_C, c))
                self.in_C = c
        return nn.Sequential(*layers)
    
    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

def VGG11():
    cfg = [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']
    return VGG(cfg)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device: ", device)
model = VGG11().to(device)

optimizer = optimizer = torch.optim.SGD(model.parameters(), lr=CONFIG['lr'], 
    momentum=CONFIG['momentum'], weight_decay=CONFIG['weight_decay'])
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=CONFIG['epoch_size'])

torchsummary.summary(model, input_size=inputs.size()[1:], device=device)
# Out:
# Device:  cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#              Block-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,728
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#               ReLU-8          [-1, 128, 16, 16]               0
#              Block-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#              ReLU-13            [-1, 256, 8, 8]               0
#             Block-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#             Block-18            [-1, 256, 8, 8]               0
#         MaxPool2d-19            [-1, 256, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-21            [-1, 512, 4, 4]           1,024
#              ReLU-22            [-1, 512, 4, 4]               0
#             Block-23            [-1, 512, 4, 4]               0
#            Conv2d-24            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-25            [-1, 512, 4, 4]           1,024
#              ReLU-26            [-1, 512, 4, 4]               0
#             Block-27            [-1, 512, 4, 4]               0
#         MaxPool2d-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,296
#       BatchNorm2d-30            [-1, 512, 2, 2]           1,024
#              ReLU-31            [-1, 512, 2, 2]               0
#             Block-32            [-1, 512, 2, 2]               0
#            Conv2d-33            [-1, 512, 2, 2]       2,359,296
#       BatchNorm2d-34            [-1, 512, 2, 2]           1,024
#              ReLU-35            [-1, 512, 2, 2]               0
#             Block-36            [-1, 512, 2, 2]               0
#         MaxPool2d-37            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-38            [-1, 512, 1, 1]               0
#           Flatten-39                  [-1, 512]               0
#            Linear-40                   [-1, 10]           5,130
# ================================================================
# Total params: 9,228,362
# Trainable params: 9,228,362
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.87
# Params size (MB): 35.20
# Estimated Total Size (MB): 40.09
# ----------------------------------------------------------------

# %% [markdown]
# ## 4. Experiment

# %%
class AverageMeter(object):
    def __init__(self, name):
        self.name = name
        self.reset()

    def reset(self):
        self.sum = 0
        self.count = 0
        self.avg = 0

    def update(self, val, n=1):
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = f'{self.name:10s} {self.avg:.3f}'
        return fmtstr


class ProgressMeter(object):
    def __init__(self, meters, loader_length, prefix=""):
        self.meters = [AverageMeter(i) for i in meters]
        self.loader_length = loader_length
        self.prefix = prefix
    
    def reset(self):
        for m in self.meters:
            m.reset()
    
    def update(self, values, n=1):
        for m, v in zip(self.meters, values):
            m.update(v, n)
            self.__setattr__(m.name, m.avg)

    def display(self, batch_idx, postfix=""):
        batch_info = f'[{batch_idx+1:03d}/{self.loader_length:03d}]'
        msg = [self.prefix + ' ' + batch_info]
        msg += [str(meter) for meter in self.meters]
        msg = ' | '.join(msg)

        sys.stdout.write('\r')
        sys.stdout.write(msg + postfix)
        sys.stdout.flush()


def accuracy(logits, targets):
    _, pred = logits.max(1)
    acc = pred.eq(targets).float().mean().item()
    return acc

def criterion(logits, targets):
    return F.cross_entropy(logits, targets)

# %%
class Trainer(object):
    def __init__(self, model, optimizer, device, scheduler=None):
        self.model = model
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.device = device
        self.best_epoch, self.best_acc = 0, 0
        

    def train(self, train_loader, epoch):
        progress = ProgressMeter(["train_loss", "train_acc"], len(train_loader), prefix=f'EP  {epoch:03d}')
        self.model.train()

        start_time = time.time()
        for idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(self.device), targets.to(self.device)
            outputs = self.model(inputs)
            loss = criterion(outputs, targets)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            acc = accuracy(outputs, targets)
            loss = loss.item()
            progress.update([loss, acc], n=inputs.size(0))
            if idx % 20 == 0:
                progress.display(idx+1)

        if self.scheduler: self.scheduler.step()
        finish_time = time.time()
        epoch_time = finish_time - start_time
        progress.display(idx, f' | {epoch_time:.0f}s' + '\n')

    
    def validate(self, val_loader, epoch):
        progress = ProgressMeter(["val_loss", "val_acc"], len(val_loader), prefix=f'VAL {epoch:03d}')
        model.eval()

        with torch.no_grad():
            for idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                acc = accuracy(outputs, targets)
                progress.update([loss, acc], n=inputs.size(0))

            if progress.val_acc > self.best_acc:
                ckpt = {
                    'best_epoch': self.best_epoch,
                    'best_acc': self.best_acc,
                    'model_state_dict': model.state_dict()
                }
                torch.save(ckpt, 'ckpt.pt')
                self.best_epoch = epoch
                self.best_acc = progress.val_acc
            
            progress.display(idx, '\n')

    
    def test(self, test_loader):
        progress = ProgressMeter(["test_loss", "test_acc"], len(test_loader), prefix=f'TEST')
        ckpt = torch.load('ckpt.pt')
        self.model.load_state_dict(ckpt['model_state_dict'])
        self.model.eval()

        with torch.no_grad():
            for idx, (inputs, targets) in enumerate(test_loader):
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = self.model(inputs)
                loss = criterion(outputs, targets)
                acc = accuracy(outputs, targets)
                progress.update([loss, acc], n=inputs.size(0))

            progress.display(idx, '\n')

# %%
trainer = Trainer(model, optimizer, device, scheduler)

# %%
for ep in range(CONFIG['epoch_size']):
    print('-' * 65)
    trainer.train(train_loader, ep)
    trainer.validate(val_loader, ep)
# Out:
# -----------------------------------------------------------------
# EP  000 [352/352] | train_loss 2.375 | train_acc  0.204 | 19s
# VAL 000 [040/040] | val_loss   1.916 | val_acc    0.255
# -----------------------------------------------------------------
# EP  001 [352/352] | train_loss 1.768 | train_acc  0.318 | 19s
# VAL 001 [040/040] | val_loss   1.650 | val_acc    0.359
# -----------------------------------------------------------------
# EP  002 [352/352] | train_loss 1.509 | train_acc  0.431 | 19s
# VAL 002 [040/040] | val_loss   1.452 | val_acc    0.465
# -----------------------------------------------------------------
# EP  003 [352/352] | train_loss 1.270 | train_acc  0.537 | 19s
# VAL 003 [040/040] | val_loss   1.241 | val_acc    0.549
# -----------------------------------------------------------------
# EP  004 [352/352] | train_loss 1.094 | train_acc  0.607 | 19s
# VAL 004 [040/040] | val_loss   1.092 | val_acc    0.622
# -----------------------------------------------------------------
# EP  005 [352/352] | train_loss 0.955 | train_acc  0.663 | 19s
# VAL 005 [040/040] | val_loss   1.058 | val_acc    0.627
# -----------------------------------------------------------------
# EP  006 [352/352] | train_loss 0.862 | train_acc  0.699 | 19s
# VAL 006 [040/040] | val_loss   0.960 | val_acc    0.664
# -----------------------------------------------------------------
# EP  007 [352/352] | train_loss 0.795 | train_acc  0.725 | 19s
# VAL 007 [040/040] | val_loss   0.867 | val_acc    0.703
# -----------------------------------------------------------------
# EP  008 [352/352] | train_loss 0.746 | train_acc  0.745 | 19s
# VAL 008 [040/040] | val_loss   0.806 | val_acc    0.726
# -----------------------------------------------------------------
# EP  009 [352/352] | train_loss 0.709 | train_acc  0.758 | 19s
# VAL 009 [040/040] | val_loss   0.760 | val_acc    0.733
# -----------------------------------------------------------------
# EP  010 [352/352] | train_loss 0.679 | train_acc  0.766 | 19s
# VAL 010 [040/040] | val_loss   1.188 | val_acc    0.640
# -----------------------------------------------------------------
# EP  011 [352/352] | train_loss 0.648 | train_acc  0.780 | 19s
# VAL 011 [040/040] | val_loss   0.834 | val_acc    0.728
# -----------------------------------------------------------------
# EP  012 [352/352] | train_loss 0.628 | train_acc  0.784 | 19s
# VAL 012 [040/040] | val_loss   0.789 | val_acc    0.740
# -----------------------------------------------------------------
# EP  013 [352/352] | train_loss 0.622 | train_acc  0.787 | 19s
# VAL 013 [040/040] | val_loss   0.729 | val_acc    0.746
# -----------------------------------------------------------------
# EP  014 [352/352] | train_loss 0.595 | train_acc  0.797 | 19s
# VAL 014 [040/040] | val_loss   0.631 | val_acc    0.786
# -----------------------------------------------------------------
# EP  015 [352/352] | train_loss 0.589 | train_acc  0.800 | 19s
# VAL 015 [040/040] | val_loss   0.942 | val_acc    0.701
# -----------------------------------------------------------------
# EP  016 [352/352] | train_loss 0.577 | train_acc  0.802 | 19s
# VAL 016 [040/040] | val_loss   0.748 | val_acc    0.754
# -----------------------------------------------------------------
# EP  017 [352/352] | train_loss 0.570 | train_acc  0.804 | 19s
# VAL 017 [040/040] | val_loss   0.778 | val_acc    0.734
# -----------------------------------------------------------------
# EP  018 [352/352] | train_loss 0.559 | train_acc  0.810 | 19s
# VAL 018 [040/040] | val_loss   0.738 | val_acc    0.758
# -----------------------------------------------------------------
# EP  019 [352/352] | train_loss 0.550 | train_acc  0.812 | 18s
# VAL 019 [040/040] | val_loss   0.782 | val_acc    0.742
# -----------------------------------------------------------------
# EP  020 [352/352] | train_loss 0.541 | train_acc  0.815 | 19s
# VAL 020 [040/040] | val_loss   0.742 | val_acc    0.747
# -----------------------------------------------------------------
# EP  021 [352/352] | train_loss 0.534 | train_acc  0.818 | 19s
# VAL 021 [040/040] | val_loss   0.798 | val_acc    0.743
# -----------------------------------------------------------------
# EP  022 [352/352] | train_loss 0.519 | train_acc  0.824 | 18s
# VAL 022 [040/040] | val_loss   0.630 | val_acc    0.790
# -----------------------------------------------------------------
# EP  023 [352/352] | train_loss 0.520 | train_acc  0.824 | 19s
# VAL 023 [040/040] | val_loss   0.661 | val_acc    0.781
# -----------------------------------------------------------------
# EP  024 [352/352] | train_loss 0.514 | train_acc  0.824 | 19s
# VAL 024 [040/040] | val_loss   0.813 | val_acc    0.740
# -----------------------------------------------------------------
# EP  025 [352/352] | train_loss 0.516 | train_acc  0.825 | 19s
# VAL 025 [040/040] | val_loss   0.930 | val_acc    0.703
# -----------------------------------------------------------------
# EP  026 [352/352] | train_loss 0.509 | train_acc  0.827 | 19s
# VAL 026 [040/040] | val_loss   0.699 | val_acc    0.764
# -----------------------------------------------------------------
# EP  027 [352/352] | train_loss 0.494 | train_acc  0.831 | 19s
# VAL 027 [040/040] | val_loss   0.728 | val_acc    0.755
# -----------------------------------------------------------------
# EP  028 [352/352] | train_loss 0.493 | train_acc  0.832 | 19s
# VAL 028 [040/040] | val_loss   0.770 | val_acc    0.752
# -----------------------------------------------------------------
# EP  029 [352/352] | train_loss 0.486 | train_acc  0.834 | 19s
# VAL 029 [040/040] | val_loss   0.674 | val_acc    0.785
# -----------------------------------------------------------------
# EP  030 [352/352] | train_loss 0.483 | train_acc  0.836 | 18s
# VAL 030 [040/040] | val_loss   0.780 | val_acc    0.751
# -----------------------------------------------------------------
# EP  031 [352/352] | train_loss 0.477 | train_acc  0.837 | 19s
# VAL 031 [040/040] | val_loss   0.674 | val_acc    0.788
# -----------------------------------------------------------------
# EP  032 [352/352] | train_loss 0.475 | train_acc  0.838 | 19s
# VAL 032 [040/040] | val_loss   0.787 | val_acc    0.734
# -----------------------------------------------------------------
# EP  033 [352/352] | train_loss 0.469 | train_acc  0.840 | 19s
# VAL 033 [040/040] | val_loss   0.657 | val_acc    0.775
# -----------------------------------------------------------------
# EP  034 [352/352] | train_loss 0.459 | train_acc  0.845 | 19s
# VAL 034 [040/040] | val_loss   0.619 | val_acc    0.792
# -----------------------------------------------------------------
# EP  035 [352/352] | train_loss 0.462 | train_acc  0.845 | 19s
# VAL 035 [040/040] | val_loss   0.743 | val_acc    0.762
# -----------------------------------------------------------------
# EP  036 [352/352] | train_loss 0.461 | train_acc  0.842 | 19s
# VAL 036 [040/040] | val_loss   0.605 | val_acc    0.802
# -----------------------------------------------------------------
# EP  037 [352/352] | train_loss 0.462 | train_acc  0.842 | 19s
# VAL 037 [040/040] | val_loss   0.975 | val_acc    0.697
# -----------------------------------------------------------------
# EP  038 [352/352] | train_loss 0.450 | train_acc  0.847 | 19s
# VAL 038 [040/040] | val_loss   0.855 | val_acc    0.722
# -----------------------------------------------------------------
# EP  039 [352/352] | train_loss 0.450 | train_acc  0.847 | 19s
# VAL 039 [040/040] | val_loss   0.680 | val_acc    0.783
# -----------------------------------------------------------------
# EP  040 [352/352] | train_loss 0.445 | train_acc  0.849 | 19s
# VAL 040 [040/040] | val_loss   0.540 | val_acc    0.821
# -----------------------------------------------------------------
# EP  041 [352/352] | train_loss 0.444 | train_acc  0.849 | 19s
# VAL 041 [040/040] | val_loss   0.655 | val_acc    0.781
# -----------------------------------------------------------------
# EP  042 [352/352] | train_loss 0.437 | train_acc  0.851 | 19s
# VAL 042 [040/040] | val_loss   0.630 | val_acc    0.791
# -----------------------------------------------------------------
# EP  043 [352/352] | train_loss 0.434 | train_acc  0.853 | 18s
# VAL 043 [040/040] | val_loss   0.594 | val_acc    0.797
# -----------------------------------------------------------------
# EP  044 [352/352] | train_loss 0.435 | train_acc  0.852 | 19s
# VAL 044 [040/040] | val_loss   0.603 | val_acc    0.801
# -----------------------------------------------------------------
# EP  045 [352/352] | train_loss 0.429 | train_acc  0.854 | 18s
# VAL 045 [040/040] | val_loss   0.673 | val_acc    0.779
# -----------------------------------------------------------------
# EP  046 [352/352] | train_loss 0.428 | train_acc  0.853 | 19s
# VAL 046 [040/040] | val_loss   0.665 | val_acc    0.781
# -----------------------------------------------------------------
# EP  047 [352/352] | train_loss 0.429 | train_acc  0.855 | 19s
# VAL 047 [040/040] | val_loss   0.618 | val_acc    0.801
# -----------------------------------------------------------------
# EP  048 [352/352] | train_loss 0.423 | train_acc  0.854 | 18s
# VAL 048 [040/040] | val_loss   0.631 | val_acc    0.788
# -----------------------------------------------------------------
# EP  049 [352/352] | train_loss 0.412 | train_acc  0.859 | 19s
# VAL 049 [040/040] | val_loss   0.754 | val_acc    0.769
# -----------------------------------------------------------------
# EP  050 [352/352] | train_loss 0.410 | train_acc  0.860 | 19s
# VAL 050 [040/040] | val_loss   0.573 | val_acc    0.814
# -----------------------------------------------------------------
# EP  051 [352/352] | train_loss 0.418 | train_acc  0.857 | 19s
# VAL 051 [040/040] | val_loss   0.648 | val_acc    0.786
# -----------------------------------------------------------------
# EP  052 [352/352] | train_loss 0.406 | train_acc  0.861 | 18s
# VAL 052 [040/040] | val_loss   0.609 | val_acc    0.787
# -----------------------------------------------------------------
# EP  053 [352/352] | train_loss 0.398 | train_acc  0.864 | 18s
# VAL 053 [040/040] | val_loss   0.749 | val_acc    0.757
# -----------------------------------------------------------------
# EP  054 [352/352] | train_loss 0.416 | train_acc  0.857 | 19s
# VAL 054 [040/040] | val_loss   0.654 | val_acc    0.789
# -----------------------------------------------------------------
# EP  055 [352/352] | train_loss 0.398 | train_acc  0.863 | 19s
# VAL 055 [040/040] | val_loss   0.556 | val_acc    0.811
# -----------------------------------------------------------------
# EP  056 [352/352] | train_loss 0.406 | train_acc  0.862 | 19s
# VAL 056 [040/040] | val_loss   0.596 | val_acc    0.806
# -----------------------------------------------------------------
# EP  057 [352/352] | train_loss 0.402 | train_acc  0.863 | 19s
# VAL 057 [040/040] | val_loss   0.747 | val_acc    0.765
# -----------------------------------------------------------------
# EP  058 [352/352] | train_loss 0.395 | train_acc  0.864 | 18s
# VAL 058 [040/040] | val_loss   0.604 | val_acc    0.797
# -----------------------------------------------------------------
# EP  059 [352/352] | train_loss 0.397 | train_acc  0.865 | 19s
# VAL 059 [040/040] | val_loss   0.594 | val_acc    0.809
# -----------------------------------------------------------------
# EP  060 [352/352] | train_loss 0.381 | train_acc  0.871 | 18s
# VAL 060 [040/040] | val_loss   0.605 | val_acc    0.801
# -----------------------------------------------------------------
# EP  061 [352/352] | train_loss 0.391 | train_acc  0.866 | 18s
# VAL 061 [040/040] | val_loss   0.534 | val_acc    0.821
# -----------------------------------------------------------------
# EP  062 [352/352] | train_loss 0.382 | train_acc  0.868 | 19s
# VAL 062 [040/040] | val_loss   0.582 | val_acc    0.814
# -----------------------------------------------------------------
# EP  063 [352/352] | train_loss 0.384 | train_acc  0.870 | 18s
# VAL 063 [040/040] | val_loss   0.699 | val_acc    0.775
# -----------------------------------------------------------------
# EP  064 [352/352] | train_loss 0.381 | train_acc  0.871 | 19s
# VAL 064 [040/040] | val_loss   0.594 | val_acc    0.803
# -----------------------------------------------------------------
# EP  065 [352/352] | train_loss 0.378 | train_acc  0.870 | 19s
# VAL 065 [040/040] | val_loss   0.547 | val_acc    0.819
# -----------------------------------------------------------------
# EP  066 [352/352] | train_loss 0.376 | train_acc  0.871 | 19s
# VAL 066 [040/040] | val_loss   0.501 | val_acc    0.838
# -----------------------------------------------------------------
# EP  067 [352/352] | train_loss 0.373 | train_acc  0.871 | 19s
# VAL 067 [040/040] | val_loss   0.643 | val_acc    0.791
# -----------------------------------------------------------------
# EP  068 [352/352] | train_loss 0.377 | train_acc  0.871 | 19s
# VAL 068 [040/040] | val_loss   0.558 | val_acc    0.814
# -----------------------------------------------------------------
# EP  069 [352/352] | train_loss 0.360 | train_acc  0.876 | 19s
# VAL 069 [040/040] | val_loss   0.559 | val_acc    0.808
# -----------------------------------------------------------------
# EP  070 [352/352] | train_loss 0.366 | train_acc  0.876 | 19s
# VAL 070 [040/040] | val_loss   0.580 | val_acc    0.815
# -----------------------------------------------------------------
# EP  071 [352/352] | train_loss 0.356 | train_acc  0.879 | 19s
# VAL 071 [040/040] | val_loss   0.492 | val_acc    0.837
# -----------------------------------------------------------------
# EP  072 [352/352] | train_loss 0.362 | train_acc  0.874 | 19s
# VAL 072 [040/040] | val_loss   0.509 | val_acc    0.829
# -----------------------------------------------------------------
# EP  073 [352/352] | train_loss 0.355 | train_acc  0.878 | 18s
# VAL 073 [040/040] | val_loss   0.635 | val_acc    0.795
# -----------------------------------------------------------------
# EP  074 [352/352] | train_loss 0.348 | train_acc  0.880 | 19s
# VAL 074 [040/040] | val_loss   0.584 | val_acc    0.810
# -----------------------------------------------------------------
# EP  075 [352/352] | train_loss 0.352 | train_acc  0.880 | 19s
# VAL 075 [040/040] | val_loss   0.529 | val_acc    0.832
# -----------------------------------------------------------------
# EP  076 [352/352] | train_loss 0.345 | train_acc  0.881 | 19s
# VAL 076 [040/040] | val_loss   0.528 | val_acc    0.823
# -----------------------------------------------------------------
# EP  077 [352/352] | train_loss 0.342 | train_acc  0.882 | 19s
# VAL 077 [040/040] | val_loss   0.565 | val_acc    0.814
# -----------------------------------------------------------------
# EP  078 [352/352] | train_loss 0.342 | train_acc  0.881 | 18s
# VAL 078 [040/040] | val_loss   0.690 | val_acc    0.776
# -----------------------------------------------------------------
# EP  079 [352/352] | train_loss 0.338 | train_acc  0.883 | 19s
# VAL 079 [040/040] | val_loss   0.542 | val_acc    0.821
# -----------------------------------------------------------------
# EP  080 [352/352] | train_loss 0.331 | train_acc  0.886 | 19s
# VAL 080 [040/040] | val_loss   0.678 | val_acc    0.788
# -----------------------------------------------------------------
# EP  081 [352/352] | train_loss 0.331 | train_acc  0.885 | 18s
# VAL 081 [040/040] | val_loss   0.719 | val_acc    0.776
# -----------------------------------------------------------------
# EP  082 [352/352] | train_loss 0.330 | train_acc  0.886 | 19s
# VAL 082 [040/040] | val_loss   0.499 | val_acc    0.835
# -----------------------------------------------------------------
# EP  083 [352/352] | train_loss 0.328 | train_acc  0.888 | 19s
# VAL 083 [040/040] | val_loss   0.769 | val_acc    0.759
# -----------------------------------------------------------------
# EP  084 [352/352] | train_loss 0.329 | train_acc  0.886 | 19s
# VAL 084 [040/040] | val_loss   0.586 | val_acc    0.806
# -----------------------------------------------------------------
# EP  085 [352/352] | train_loss 0.323 | train_acc  0.888 | 18s
# VAL 085 [040/040] | val_loss   0.497 | val_acc    0.834
# -----------------------------------------------------------------
# EP  086 [352/352] | train_loss 0.316 | train_acc  0.891 | 19s
# VAL 086 [040/040] | val_loss   0.582 | val_acc    0.822
# -----------------------------------------------------------------
# EP  087 [352/352] | train_loss 0.315 | train_acc  0.893 | 19s
# VAL 087 [040/040] | val_loss   0.492 | val_acc    0.836
# -----------------------------------------------------------------
# EP  088 [352/352] | train_loss 0.311 | train_acc  0.895 | 18s
# VAL 088 [040/040] | val_loss   0.602 | val_acc    0.811
# -----------------------------------------------------------------
# EP  089 [352/352] | train_loss 0.303 | train_acc  0.896 | 19s
# VAL 089 [040/040] | val_loss   0.492 | val_acc    0.836
# -----------------------------------------------------------------
# EP  090 [352/352] | train_loss 0.308 | train_acc  0.893 | 19s
# VAL 090 [040/040] | val_loss   0.657 | val_acc    0.800
# -----------------------------------------------------------------
# EP  091 [352/352] | train_loss 0.289 | train_acc  0.901 | 19s
# VAL 091 [040/040] | val_loss   0.520 | val_acc    0.833
# -----------------------------------------------------------------
# EP  092 [352/352] | train_loss 0.302 | train_acc  0.896 | 19s
# VAL 092 [040/040] | val_loss   0.534 | val_acc    0.823
# -----------------------------------------------------------------
# EP  093 [352/352] | train_loss 0.296 | train_acc  0.897 | 18s
# VAL 093 [040/040] | val_loss   0.637 | val_acc    0.810
# -----------------------------------------------------------------
# EP  094 [352/352] | train_loss 0.289 | train_acc  0.900 | 19s
# VAL 094 [040/040] | val_loss   0.560 | val_acc    0.824
# -----------------------------------------------------------------
# EP  095 [352/352] | train_loss 0.288 | train_acc  0.901 | 19s
# VAL 095 [040/040] | val_loss   0.511 | val_acc    0.834
# -----------------------------------------------------------------
# EP  096 [352/352] | train_loss 0.290 | train_acc  0.901 | 18s
# VAL 096 [040/040] | val_loss   0.519 | val_acc    0.834
# -----------------------------------------------------------------
# EP  097 [352/352] | train_loss 0.278 | train_acc  0.904 | 19s
# VAL 097 [040/040] | val_loss   0.518 | val_acc    0.839
# -----------------------------------------------------------------
# EP  098 [352/352] | train_loss 0.277 | train_acc  0.906 | 18s
# VAL 098 [040/040] | val_loss   0.512 | val_acc    0.835
# -----------------------------------------------------------------
# EP  099 [352/352] | train_loss 0.274 | train_acc  0.906 | 19s
# VAL 099 [040/040] | val_loss   0.511 | val_acc    0.831
# -----------------------------------------------------------------
# EP  100 [352/352] | train_loss 0.265 | train_acc  0.909 | 19s
# VAL 100 [040/040] | val_loss   0.518 | val_acc    0.834
# -----------------------------------------------------------------
# EP  101 [352/352] | train_loss 0.266 | train_acc  0.908 | 19s
# VAL 101 [040/040] | val_loss   0.511 | val_acc    0.835
# -----------------------------------------------------------------
# EP  102 [352/352] | train_loss 0.257 | train_acc  0.911 | 19s
# VAL 102 [040/040] | val_loss   0.472 | val_acc    0.849
# -----------------------------------------------------------------
# EP  103 [352/352] | train_loss 0.269 | train_acc  0.907 | 19s
# VAL 103 [040/040] | val_loss   0.552 | val_acc    0.816
# -----------------------------------------------------------------
# EP  104 [352/352] | train_loss 0.249 | train_acc  0.915 | 18s
# VAL 104 [040/040] | val_loss   0.491 | val_acc    0.847
# -----------------------------------------------------------------
# EP  105 [352/352] | train_loss 0.252 | train_acc  0.912 | 19s
# VAL 105 [040/040] | val_loss   0.549 | val_acc    0.829
# -----------------------------------------------------------------
# EP  106 [352/352] | train_loss 0.255 | train_acc  0.912 | 18s
# VAL 106 [040/040] | val_loss   0.498 | val_acc    0.839
# -----------------------------------------------------------------
# EP  107 [352/352] | train_loss 0.245 | train_acc  0.916 | 19s
# VAL 107 [040/040] | val_loss   0.518 | val_acc    0.837
# -----------------------------------------------------------------
# EP  108 [352/352] | train_loss 0.243 | train_acc  0.916 | 19s
# VAL 108 [040/040] | val_loss   0.501 | val_acc    0.840
# -----------------------------------------------------------------
# EP  109 [352/352] | train_loss 0.235 | train_acc  0.918 | 19s
# VAL 109 [040/040] | val_loss   0.492 | val_acc    0.848
# -----------------------------------------------------------------
# EP  110 [352/352] | train_loss 0.234 | train_acc  0.919 | 19s
# VAL 110 [040/040] | val_loss   0.538 | val_acc    0.838
# -----------------------------------------------------------------
# EP  111 [352/352] | train_loss 0.228 | train_acc  0.920 | 18s
# VAL 111 [040/040] | val_loss   0.463 | val_acc    0.852
# -----------------------------------------------------------------
# EP  112 [352/352] | train_loss 0.231 | train_acc  0.919 | 19s
# VAL 112 [040/040] | val_loss   0.456 | val_acc    0.857
# -----------------------------------------------------------------
# EP  113 [352/352] | train_loss 0.225 | train_acc  0.923 | 19s
# VAL 113 [040/040] | val_loss   0.494 | val_acc    0.845
# -----------------------------------------------------------------
# EP  114 [352/352] | train_loss 0.216 | train_acc  0.924 | 18s
# VAL 114 [040/040] | val_loss   0.575 | val_acc    0.827
# -----------------------------------------------------------------
# EP  115 [352/352] | train_loss 0.211 | train_acc  0.927 | 19s
# VAL 115 [040/040] | val_loss   0.537 | val_acc    0.825
# -----------------------------------------------------------------
# EP  116 [352/352] | train_loss 0.208 | train_acc  0.928 | 18s
# VAL 116 [040/040] | val_loss   0.459 | val_acc    0.859
# -----------------------------------------------------------------
# EP  117 [352/352] | train_loss 0.208 | train_acc  0.928 | 19s
# VAL 117 [040/040] | val_loss   0.433 | val_acc    0.862
# -----------------------------------------------------------------
# EP  118 [352/352] | train_loss 0.206 | train_acc  0.928 | 19s
# VAL 118 [040/040] | val_loss   0.510 | val_acc    0.841
# -----------------------------------------------------------------
# EP  119 [352/352] | train_loss 0.201 | train_acc  0.929 | 19s
# VAL 119 [040/040] | val_loss   0.481 | val_acc    0.850
# -----------------------------------------------------------------
# EP  120 [352/352] | train_loss 0.192 | train_acc  0.934 | 19s
# VAL 120 [040/040] | val_loss   0.471 | val_acc    0.855
# -----------------------------------------------------------------
# EP  121 [352/352] | train_loss 0.192 | train_acc  0.934 | 19s
# VAL 121 [040/040] | val_loss   0.441 | val_acc    0.858
# -----------------------------------------------------------------
# EP  122 [352/352] | train_loss 0.192 | train_acc  0.933 | 19s
# VAL 122 [040/040] | val_loss   0.473 | val_acc    0.855
# -----------------------------------------------------------------
# EP  123 [352/352] | train_loss 0.184 | train_acc  0.936 | 19s
# VAL 123 [040/040] | val_loss   0.466 | val_acc    0.859
# -----------------------------------------------------------------
# EP  124 [352/352] | train_loss 0.178 | train_acc  0.938 | 19s
# VAL 124 [040/040] | val_loss   0.452 | val_acc    0.859
# -----------------------------------------------------------------
# EP  125 [352/352] | train_loss 0.175 | train_acc  0.939 | 19s
# VAL 125 [040/040] | val_loss   0.486 | val_acc    0.850
# -----------------------------------------------------------------
# EP  126 [352/352] | train_loss 0.177 | train_acc  0.939 | 19s
# VAL 126 [040/040] | val_loss   0.448 | val_acc    0.860
# -----------------------------------------------------------------
# EP  127 [352/352] | train_loss 0.171 | train_acc  0.941 | 18s
# VAL 127 [040/040] | val_loss   0.449 | val_acc    0.864
# -----------------------------------------------------------------
# EP  128 [352/352] | train_loss 0.165 | train_acc  0.942 | 19s
# VAL 128 [040/040] | val_loss   0.443 | val_acc    0.865
# -----------------------------------------------------------------
# EP  129 [352/352] | train_loss 0.155 | train_acc  0.946 | 18s
# VAL 129 [040/040] | val_loss   0.482 | val_acc    0.858
# -----------------------------------------------------------------
# EP  130 [352/352] | train_loss 0.155 | train_acc  0.946 | 19s
# VAL 130 [040/040] | val_loss   0.452 | val_acc    0.859
# -----------------------------------------------------------------
# EP  131 [352/352] | train_loss 0.149 | train_acc  0.948 | 19s
# VAL 131 [040/040] | val_loss   0.448 | val_acc    0.862
# -----------------------------------------------------------------
# EP  132 [352/352] | train_loss 0.140 | train_acc  0.952 | 19s
# VAL 132 [040/040] | val_loss   0.448 | val_acc    0.864
# -----------------------------------------------------------------
# EP  133 [352/352] | train_loss 0.139 | train_acc  0.952 | 19s
# VAL 133 [040/040] | val_loss   0.496 | val_acc    0.857
# -----------------------------------------------------------------
# EP  134 [352/352] | train_loss 0.140 | train_acc  0.952 | 18s
# VAL 134 [040/040] | val_loss   0.530 | val_acc    0.845
# -----------------------------------------------------------------
# EP  135 [352/352] | train_loss 0.133 | train_acc  0.954 | 19s
# VAL 135 [040/040] | val_loss   0.455 | val_acc    0.873
# -----------------------------------------------------------------
# EP  136 [352/352] | train_loss 0.129 | train_acc  0.955 | 19s
# VAL 136 [040/040] | val_loss   0.464 | val_acc    0.866
# -----------------------------------------------------------------
# EP  137 [352/352] | train_loss 0.128 | train_acc  0.956 | 19s
# VAL 137 [040/040] | val_loss   0.449 | val_acc    0.867
# -----------------------------------------------------------------
# EP  138 [352/352] | train_loss 0.121 | train_acc  0.959 | 19s
# VAL 138 [040/040] | val_loss   0.479 | val_acc    0.866
# -----------------------------------------------------------------
# EP  139 [352/352] | train_loss 0.115 | train_acc  0.960 | 19s
# VAL 139 [040/040] | val_loss   0.454 | val_acc    0.873
# -----------------------------------------------------------------
# EP  140 [352/352] | train_loss 0.113 | train_acc  0.960 | 19s
# VAL 140 [040/040] | val_loss   0.458 | val_acc    0.872
# -----------------------------------------------------------------
# EP  141 [352/352] | train_loss 0.111 | train_acc  0.962 | 19s
# VAL 141 [040/040] | val_loss   0.454 | val_acc    0.873
# -----------------------------------------------------------------
# EP  142 [352/352] | train_loss 0.102 | train_acc  0.965 | 19s
# VAL 142 [040/040] | val_loss   0.455 | val_acc    0.865
# -----------------------------------------------------------------
# EP  143 [352/352] | train_loss 0.098 | train_acc  0.966 | 19s
# VAL 143 [040/040] | val_loss   0.423 | val_acc    0.880
# -----------------------------------------------------------------
# EP  144 [352/352] | train_loss 0.100 | train_acc  0.966 | 19s
# VAL 144 [040/040] | val_loss   0.462 | val_acc    0.871
# -----------------------------------------------------------------
# EP  145 [352/352] | train_loss 0.093 | train_acc  0.969 | 19s
# VAL 145 [040/040] | val_loss   0.414 | val_acc    0.878
# -----------------------------------------------------------------
# EP  146 [352/352] | train_loss 0.089 | train_acc  0.969 | 19s
# VAL 146 [040/040] | val_loss   0.436 | val_acc    0.880
# -----------------------------------------------------------------
# EP  147 [352/352] | train_loss 0.080 | train_acc  0.973 | 18s
# VAL 147 [040/040] | val_loss   0.480 | val_acc    0.866
# -----------------------------------------------------------------
# EP  148 [352/352] | train_loss 0.084 | train_acc  0.971 | 19s
# VAL 148 [040/040] | val_loss   0.417 | val_acc    0.881
# -----------------------------------------------------------------
# EP  149 [352/352] | train_loss 0.075 | train_acc  0.974 | 19s
# VAL 149 [040/040] | val_loss   0.431 | val_acc    0.878
# -----------------------------------------------------------------
# EP  150 [352/352] | train_loss 0.075 | train_acc  0.974 | 18s
# VAL 150 [040/040] | val_loss   0.426 | val_acc    0.881
# -----------------------------------------------------------------
# EP  151 [352/352] | train_loss 0.070 | train_acc  0.976 | 19s
# VAL 151 [040/040] | val_loss   0.431 | val_acc    0.878
# -----------------------------------------------------------------
# EP  152 [352/352] | train_loss 0.066 | train_acc  0.976 | 19s
# VAL 152 [040/040] | val_loss   0.485 | val_acc    0.876
# -----------------------------------------------------------------
# EP  153 [352/352] | train_loss 0.063 | train_acc  0.978 | 19s
# VAL 153 [040/040] | val_loss   0.434 | val_acc    0.884
# -----------------------------------------------------------------
# EP  154 [352/352] | train_loss 0.058 | train_acc  0.981 | 19s
# VAL 154 [040/040] | val_loss   0.437 | val_acc    0.889
# -----------------------------------------------------------------
# EP  155 [352/352] | train_loss 0.049 | train_acc  0.983 | 19s
# VAL 155 [040/040] | val_loss   0.449 | val_acc    0.885
# -----------------------------------------------------------------
# EP  156 [352/352] | train_loss 0.050 | train_acc  0.983 | 19s
# VAL 156 [040/040] | val_loss   0.441 | val_acc    0.883
# -----------------------------------------------------------------
# EP  157 [352/352] | train_loss 0.050 | train_acc  0.982 | 19s
# VAL 157 [040/040] | val_loss   0.463 | val_acc    0.882
# -----------------------------------------------------------------
# EP  158 [352/352] | train_loss 0.048 | train_acc  0.984 | 19s
# VAL 158 [040/040] | val_loss   0.411 | val_acc    0.895
# -----------------------------------------------------------------
# EP  159 [352/352] | train_loss 0.040 | train_acc  0.986 | 19s
# VAL 159 [040/040] | val_loss   0.416 | val_acc    0.891
# -----------------------------------------------------------------
# EP  160 [352/352] | train_loss 0.036 | train_acc  0.988 | 19s
# VAL 160 [040/040] | val_loss   0.426 | val_acc    0.891
# -----------------------------------------------------------------
# EP  161 [352/352] | train_loss 0.036 | train_acc  0.988 | 19s
# VAL 161 [040/040] | val_loss   0.419 | val_acc    0.893
# -----------------------------------------------------------------
# EP  162 [352/352] | train_loss 0.027 | train_acc  0.991 | 19s
# VAL 162 [040/040] | val_loss   0.403 | val_acc    0.900
# -----------------------------------------------------------------
# EP  163 [352/352] | train_loss 0.023 | train_acc  0.992 | 19s
# VAL 163 [040/040] | val_loss   0.452 | val_acc    0.889
# -----------------------------------------------------------------
# EP  164 [352/352] | train_loss 0.025 | train_acc  0.992 | 19s
# VAL 164 [040/040] | val_loss   0.412 | val_acc    0.898
# -----------------------------------------------------------------
# EP  165 [352/352] | train_loss 0.022 | train_acc  0.993 | 18s
# VAL 165 [040/040] | val_loss   0.444 | val_acc    0.894
# -----------------------------------------------------------------
# EP  166 [352/352] | train_loss 0.021 | train_acc  0.993 | 19s
# VAL 166 [040/040] | val_loss   0.432 | val_acc    0.898
# -----------------------------------------------------------------
# EP  167 [352/352] | train_loss 0.017 | train_acc  0.995 | 19s
# VAL 167 [040/040] | val_loss   0.413 | val_acc    0.902
# -----------------------------------------------------------------
# EP  168 [352/352] | train_loss 0.016 | train_acc  0.995 | 19s
# VAL 168 [040/040] | val_loss   0.403 | val_acc    0.905
# -----------------------------------------------------------------
# EP  169 [352/352] | train_loss 0.013 | train_acc  0.996 | 19s
# VAL 169 [040/040] | val_loss   0.385 | val_acc    0.904
# -----------------------------------------------------------------
# EP  170 [352/352] | train_loss 0.011 | train_acc  0.997 | 18s
# VAL 170 [040/040] | val_loss   0.393 | val_acc    0.902
# -----------------------------------------------------------------
# EP  171 [352/352] | train_loss 0.010 | train_acc  0.997 | 19s
# VAL 171 [040/040] | val_loss   0.399 | val_acc    0.904
# -----------------------------------------------------------------
# EP  172 [352/352] | train_loss 0.009 | train_acc  0.997 | 19s
# VAL 172 [040/040] | val_loss   0.397 | val_acc    0.906
# -----------------------------------------------------------------
# EP  173 [352/352] | train_loss 0.008 | train_acc  0.998 | 19s
# VAL 173 [040/040] | val_loss   0.367 | val_acc    0.910
# -----------------------------------------------------------------
# EP  174 [352/352] | train_loss 0.006 | train_acc  0.999 | 19s
# VAL 174 [040/040] | val_loss   0.384 | val_acc    0.909
# -----------------------------------------------------------------
# EP  175 [352/352] | train_loss 0.006 | train_acc  0.998 | 19s
# VAL 175 [040/040] | val_loss   0.374 | val_acc    0.909
# -----------------------------------------------------------------
# EP  176 [352/352] | train_loss 0.005 | train_acc  0.999 | 19s
# VAL 176 [040/040] | val_loss   0.374 | val_acc    0.910
# -----------------------------------------------------------------
# EP  177 [352/352] | train_loss 0.004 | train_acc  0.999 | 19s
# VAL 177 [040/040] | val_loss   0.374 | val_acc    0.910
# -----------------------------------------------------------------
# EP  178 [352/352] | train_loss 0.004 | train_acc  0.999 | 19s
# VAL 178 [040/040] | val_loss   0.391 | val_acc    0.907
# -----------------------------------------------------------------
# EP  179 [352/352] | train_loss 0.004 | train_acc  0.999 | 19s
# VAL 179 [040/040] | val_loss   0.377 | val_acc    0.911
# -----------------------------------------------------------------
# EP  180 [352/352] | train_loss 0.003 | train_acc  0.999 | 19s
# VAL 180 [040/040] | val_loss   0.381 | val_acc    0.911
# -----------------------------------------------------------------
# EP  181 [352/352] | train_loss 0.003 | train_acc  0.999 | 19s
# VAL 181 [040/040] | val_loss   0.363 | val_acc    0.913
# -----------------------------------------------------------------
# EP  182 [352/352] | train_loss 0.003 | train_acc  0.999 | 19s
# VAL 182 [040/040] | val_loss   0.363 | val_acc    0.911
# -----------------------------------------------------------------
# EP  183 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 183 [040/040] | val_loss   0.365 | val_acc    0.915
# -----------------------------------------------------------------
# EP  184 [352/352] | train_loss 0.003 | train_acc  0.999 | 19s
# VAL 184 [040/040] | val_loss   0.381 | val_acc    0.911
# -----------------------------------------------------------------
# EP  185 [352/352] | train_loss 0.003 | train_acc  1.000 | 19s
# VAL 185 [040/040] | val_loss   0.352 | val_acc    0.913
# -----------------------------------------------------------------
# EP  186 [352/352] | train_loss 0.002 | train_acc  1.000 | 18s
# VAL 186 [040/040] | val_loss   0.368 | val_acc    0.908
# -----------------------------------------------------------------
# EP  187 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 187 [040/040] | val_loss   0.382 | val_acc    0.907
# -----------------------------------------------------------------
# EP  188 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 188 [040/040] | val_loss   0.348 | val_acc    0.917
# -----------------------------------------------------------------
# EP  189 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 189 [040/040] | val_loss   0.368 | val_acc    0.910
# -----------------------------------------------------------------
# EP  190 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 190 [040/040] | val_loss   0.368 | val_acc    0.912
# -----------------------------------------------------------------
# EP  191 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 191 [040/040] | val_loss   0.353 | val_acc    0.916
# -----------------------------------------------------------------
# EP  192 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 192 [040/040] | val_loss   0.347 | val_acc    0.915
# -----------------------------------------------------------------
# EP  193 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 193 [040/040] | val_loss   0.366 | val_acc    0.913
# -----------------------------------------------------------------
# EP  194 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 194 [040/040] | val_loss   0.373 | val_acc    0.912
# -----------------------------------------------------------------
# EP  195 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 195 [040/040] | val_loss   0.343 | val_acc    0.917
# -----------------------------------------------------------------
# EP  196 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 196 [040/040] | val_loss   0.368 | val_acc    0.913
# -----------------------------------------------------------------
# EP  197 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 197 [040/040] | val_loss   0.351 | val_acc    0.912
# -----------------------------------------------------------------
# EP  198 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 198 [040/040] | val_loss   0.358 | val_acc    0.911
# -----------------------------------------------------------------
# EP  199 [352/352] | train_loss 0.002 | train_acc  1.000 | 19s
# VAL 199 [040/040] | val_loss   0.357 | val_acc    0.911

# %%
trainer.test(test_loader)
# Out:
# TEST [079/079] | test_loss  0.328 | test_acc   0.920
