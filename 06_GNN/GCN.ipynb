# %% [markdown]
# # GCN

# %% [markdown]
# ## 0. Paper

# %% [markdown]
# ### Info
# * Title: Semi-Supervised Classification with Graph Convolutional Networks
# * Author: Thomas N. Kipf
# * Task: Node Classification
# * Link: https://arxiv.org/abs/1609.02907
#
#
# ### Features
# * Dataset: cora, [link](https://github.com/tkipf/pygcn/tree/master/data/cora)
#
# ### Reference
# * https://github.com/tkipf/pygcn

# %% [markdown]
# ## 1. Setting

# %%
import os
import math
from glob import glob
from tqdm.auto import tqdm

import numpy as np
import pandas as pd
import scipy.sparse as sp
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchsummary import torchsummary

# %%
class CONFIG:
    lr = 0.01
    weight_decay = 5e-4
    drop_rate = 0.5
    hidden_dim = 16
    epoch_size = 200
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    dataset = 'cora'
    base_dir = '/content/drive/Shared drives/Yoon/Project/Doing/Deep Learning Paper Implementation'

# %% [markdown]
# ## 2. Data

# %%
def load_data():
    content = np.genfromtxt('data/cora.content', dtype=str)
    feature = sp.csr_matrix(content[:,1:-1], dtype=np.float32)
    index = np.array(content[:,0], dtype=np.int32)
    label = LabelEncoder().fit_transform(content[:,-1])

    index_dict = {j:i for i,j in enumerate(index)}
    edges = np.genfromtxt('data/cora.cites', dtype=int)
    edges = np.array(list(map(index_dict.get, edges.flatten()))).reshape((-1, 2))

    data = np.ones(edges.shape[0]) # the entries of the matrix 
    i, j = edges[:, 0], edges[:, 1] # row/column indices of the matrix entries
    M, N = label.shape[0], label.shape[0]
    adj = sp.coo_matrix((data, (i, j)), shape=(M, N), dtype=np.float32) # A[i[k], j[k]] = data[k]
    adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj) # build symmetric adjacency matrix (directed -> undirected)

    feature = normalize_row(feature)
    adj = normalize_row(adj + sp.eye(adj.shape[0]))

    train_idx, val_idx, test_idx = range(140), range(200, 500), range(500, 1500)
    feature = torch.FloatTensor(feature.toarray())
    label = torch.LongTensor(label)
    adj = sparse2torch(adj)

    train_idx = torch.LongTensor(train_idx)
    val_idx = torch.LongTensor(val_idx)
    test_idx = torch.LongTensor(test_idx)
    return adj, feature, label, train_idx, val_idx, test_idx

def normalize_row(mx):
    row_sum = np.array(mx.sum(1))
    r_inv = np.power(row_sum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_inv = sp.diags(r_inv)
    mx = r_inv.dot(mx)
    return mx

def sparse2torch(mx):
    mx = mx.tocoo().astype(np.float32)
    indices = torch.from_numpy(np.vstack((mx.row, mx.col)).astype(np.int64))
    values = torch.from_numpy(mx.data)
    shape = torch.Size(mx.shape)
    return torch.sparse.FloatTensor(indices, values, shape)

# %%
data_path = os.path.join(CONFIG.base_dir, 'data', CONFIG.dataset)
# !unzip -q "{data_path}" -d 'data'

# %%
adj, feature, label, train_idx, val_idx, test_idx = load_data()

# %%
print('adj: ', adj.size())
print('feature: ', feature.size())
print('label: ', label.size())
print('train_idx: ', train_idx.size())
print('val_idx: ', val_idx.size())
print('test_idx: ', test_idx.size())
# Out:
# adj:  torch.Size([2708, 2708])
# feature:  torch.Size([2708, 1433])
# label:  torch.Size([2708])
# train_idx:  torch.Size([140])
# val_idx:  torch.Size([300])
# test_idx:  torch.Size([1000])

# %% [markdown]
# ## 3. Model

# %%
class GraphConv(nn.Module):
    def __init__(self, in_features, out_features, bias=True):
        super(GraphConv, self).__init__()
        self.in_features= in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.FloatTensor(in_features, out_features))
        if bias:
            self.bias = nn.Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.initialize()
    
    def initialize(self):
        std = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-std, std)
        if self.bias is not None:
            self.bias.data.uniform_(-std, std)
    
    def forward(self, x, adj):
        support = torch.mm(x, self.weight) # (num_nodes, out_features)
        outputs = torch.spmm(adj, support) # (num_nodes, out_features)
        if self.bias is not None:
            outputs += self.bias
        return outputs

# %%
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, n_class, drop_rate):
        super(GCN, self).__init__()
        self.gconv1 = GraphConv(input_dim, hidden_dim)
        self.gconv2 = GraphConv(hidden_dim, n_class)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(drop_rate)
    
    def forward(self, x, adj):
        x = self.gconv1(x, adj)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.gconv2(x, adj)
        return x

# %% [markdown]
# ## 4. Experiment

# %%
class AverageMeter(object):
    def __init__(self, name):
        self.name = name
        self.reset()

    def reset(self):
        self.sum = 0
        self.count = 0
        self.avg = 0

    def update(self, val, n=1):
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = f'{self.name:10s} {self.avg:.3f}'
        return fmtstr


class ProgressMeter(object):
    def __init__(self, meters):
        self.meters = [AverageMeter(m) for m in meters]
    
    def reset(self):
        for m in self.meters:
            m.reset()
    
    def update(self, values, n=1):
        for m, v in zip(self.meters, values):
            m.update(v, n)
            self.__setattr__(m.name, m.avg)

    def log(self):
        msg = [str(meter) for meter in self.meters]
        msg = ' | '.join(msg)
        return msg


def accuracy(logits, targets):
    _, preds = logits.max(1)
    acc = (preds == targets).float().mean()
    return acc

# %%
class Trainer(object):
    def __init__(self, model, criterion, optimizer):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.best_epoch, self.best_score = 0, 0
        

    def train(self, adj, feature, label, train_idx, epoch):
        progress = ProgressMeter(["train_loss", "train_acc"])
        self.model.train()
        outputs = self.model(feature, adj)
        loss = self.criterion(outputs[train_idx], label[train_idx])
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        loss = loss.item()
        acc = accuracy(outputs[train_idx], label[train_idx]).item()
        progress.update([loss, acc], n=feature.size(0))
        print(f'TRAIN {epoch:03d} | {progress.log()}')
    
    def validate(self, adj, feature, label, val_idx,  epoch):
        progress = ProgressMeter(["valid_loss", "valid_acc"])
        self.model.eval()

        with torch.no_grad():
            outputs = self.model(feature, adj)
            loss = self.criterion(outputs[val_idx], label[val_idx])
            loss = loss.item()
            acc = accuracy(outputs[val_idx], label[val_idx]).item()
        
        progress.update([loss, acc], n=feature.size(0))
        print(f'VALID {epoch:03d} | {progress.log()}')

        if progress.valid_acc > self.best_score:
            self.best_epoch = epoch
            self.best_score = progress.valid_acc
            ckpt = {
                'best_epoch': self.best_epoch,
                'best_score': self.best_score,
                'model_state_dict': self.model.state_dict()
            }
            torch.save(ckpt, 'ckpt.pt')

    
    def test(self, adj, feature, label, test_idx):
        progress = ProgressMeter(["test_loss", "test_acc"])
        ckpt = torch.load('ckpt.pt')
        self.model.load_state_dict(ckpt['model_state_dict'])
        self.model.eval()

        with torch.no_grad():
            outputs = self.model(feature, adj)
            loss = self.criterion(outputs[test_idx], label[test_idx])
            loss = loss.item()
            acc = accuracy(outputs[test_idx], label[test_idx]).item()
        
        progress.update([loss, acc], n=feature.size(0))
        print(f'TEST | {progress.log()}')

# %%
adj, feature, label, train_idx, val_idx, test_idx = load_data()
adj, feature, label, train_idx, val_idx, test_idx = adj.to(CONFIG.device), feature.to(CONFIG.device), label.to(CONFIG.device), train_idx.to(CONFIG.device), val_idx.to(CONFIG.device), test_idx.to(CONFIG.device)
model = GCN(
    input_dim = feature.shape[1],
    hidden_dim = CONFIG.hidden_dim,
    n_class = 7,
    drop_rate = CONFIG.drop_rate
)
model.to(CONFIG.device)

criterion = nn.CrossEntropyLoss().to(CONFIG.device)
optimizer = torch.optim.Adam(model.parameters(), CONFIG.lr, weight_decay=CONFIG.weight_decay)
trainer = Trainer(model, criterion, optimizer)

# %%
for ep in range(CONFIG.epoch_size):
    print('=' * 65)
    trainer.train(adj, feature, label, train_idx, ep)
    trainer.validate(adj, feature, label, val_idx, ep)
# Out:
# =================================================================
# TRAIN 000 | train_loss 1.983 | train_acc  0.079
# VALID 000 | valid_loss 1.930 | valid_acc  0.270
# =================================================================
# TRAIN 001 | train_loss 1.959 | train_acc  0.179
# VALID 001 | valid_loss 1.915 | valid_acc  0.350
# =================================================================
# TRAIN 002 | train_loss 1.945 | train_acc  0.264
# VALID 002 | valid_loss 1.902 | valid_acc  0.350
# =================================================================
# TRAIN 003 | train_loss 1.929 | train_acc  0.293
# VALID 003 | valid_loss 1.890 | valid_acc  0.350
# =================================================================
# TRAIN 004 | train_loss 1.921 | train_acc  0.293
# VALID 004 | valid_loss 1.878 | valid_acc  0.350
# =================================================================
# TRAIN 005 | train_loss 1.909 | train_acc  0.293
# VALID 005 | valid_loss 1.866 | valid_acc  0.350
# =================================================================
# TRAIN 006 | train_loss 1.894 | train_acc  0.293
# VALID 006 | valid_loss 1.856 | valid_acc  0.350
# =================================================================
# TRAIN 007 | train_loss 1.884 | train_acc  0.293
# VALID 007 | valid_loss 1.845 | valid_acc  0.350
# =================================================================
# TRAIN 008 | train_loss 1.880 | train_acc  0.293
# VALID 008 | valid_loss 1.836 | valid_acc  0.350
# =================================================================
# TRAIN 009 | train_loss 1.868 | train_acc  0.293
# VALID 009 | valid_loss 1.827 | valid_acc  0.350
# =================================================================
# TRAIN 010 | train_loss 1.860 | train_acc  0.293
# VALID 010 | valid_loss 1.818 | valid_acc  0.350
# =================================================================
# TRAIN 011 | train_loss 1.843 | train_acc  0.293
# VALID 011 | valid_loss 1.809 | valid_acc  0.350
# =================================================================
# TRAIN 012 | train_loss 1.846 | train_acc  0.293
# VALID 012 | valid_loss 1.801 | valid_acc  0.350
# =================================================================
# TRAIN 013 | train_loss 1.838 | train_acc  0.293
# VALID 013 | valid_loss 1.793 | valid_acc  0.350
# =================================================================
# TRAIN 014 | train_loss 1.831 | train_acc  0.293
# VALID 014 | valid_loss 1.785 | valid_acc  0.350
# =================================================================
# TRAIN 015 | train_loss 1.841 | train_acc  0.293
# VALID 015 | valid_loss 1.778 | valid_acc  0.350
# =================================================================
# TRAIN 016 | train_loss 1.807 | train_acc  0.293
# VALID 016 | valid_loss 1.772 | valid_acc  0.350
# =================================================================
# TRAIN 017 | train_loss 1.805 | train_acc  0.293
# VALID 017 | valid_loss 1.766 | valid_acc  0.350
# =================================================================
# TRAIN 018 | train_loss 1.798 | train_acc  0.293
# VALID 018 | valid_loss 1.760 | valid_acc  0.350
# =================================================================
# TRAIN 019 | train_loss 1.782 | train_acc  0.293
# VALID 019 | valid_loss 1.754 | valid_acc  0.350
# =================================================================
# TRAIN 020 | train_loss 1.781 | train_acc  0.293
# VALID 020 | valid_loss 1.748 | valid_acc  0.350
# =================================================================
# TRAIN 021 | train_loss 1.760 | train_acc  0.293
# VALID 021 | valid_loss 1.742 | valid_acc  0.350
# =================================================================
# TRAIN 022 | train_loss 1.767 | train_acc  0.293
# VALID 022 | valid_loss 1.737 | valid_acc  0.350
# =================================================================
# TRAIN 023 | train_loss 1.745 | train_acc  0.293
# VALID 023 | valid_loss 1.731 | valid_acc  0.350
# =================================================================
# TRAIN 024 | train_loss 1.730 | train_acc  0.293
# VALID 024 | valid_loss 1.726 | valid_acc  0.350
# =================================================================
# TRAIN 025 | train_loss 1.727 | train_acc  0.293
# VALID 025 | valid_loss 1.721 | valid_acc  0.350
# =================================================================
# TRAIN 026 | train_loss 1.736 | train_acc  0.293
# VALID 026 | valid_loss 1.715 | valid_acc  0.350
# =================================================================
# TRAIN 027 | train_loss 1.713 | train_acc  0.293
# VALID 027 | valid_loss 1.710 | valid_acc  0.350
# =================================================================
# TRAIN 028 | train_loss 1.731 | train_acc  0.293
# VALID 028 | valid_loss 1.704 | valid_acc  0.350
# =================================================================
# TRAIN 029 | train_loss 1.707 | train_acc  0.293
# VALID 029 | valid_loss 1.699 | valid_acc  0.350
# =================================================================
# TRAIN 030 | train_loss 1.694 | train_acc  0.293
# VALID 030 | valid_loss 1.693 | valid_acc  0.350
# =================================================================
# TRAIN 031 | train_loss 1.666 | train_acc  0.293
# VALID 031 | valid_loss 1.687 | valid_acc  0.350
# =================================================================
# TRAIN 032 | train_loss 1.675 | train_acc  0.300
# VALID 032 | valid_loss 1.681 | valid_acc  0.350
# =================================================================
# TRAIN 033 | train_loss 1.655 | train_acc  0.293
# VALID 033 | valid_loss 1.675 | valid_acc  0.350
# =================================================================
# TRAIN 034 | train_loss 1.676 | train_acc  0.286
# VALID 034 | valid_loss 1.668 | valid_acc  0.350
# =================================================================
# TRAIN 035 | train_loss 1.633 | train_acc  0.329
# VALID 035 | valid_loss 1.661 | valid_acc  0.350
# =================================================================
# TRAIN 036 | train_loss 1.625 | train_acc  0.314
# VALID 036 | valid_loss 1.653 | valid_acc  0.350
# =================================================================
# TRAIN 037 | train_loss 1.621 | train_acc  0.329
# VALID 037 | valid_loss 1.645 | valid_acc  0.350
# =================================================================
# TRAIN 038 | train_loss 1.621 | train_acc  0.307
# VALID 038 | valid_loss 1.637 | valid_acc  0.347
# =================================================================
# TRAIN 039 | train_loss 1.609 | train_acc  0.364
# VALID 039 | valid_loss 1.628 | valid_acc  0.347
# =================================================================
# TRAIN 040 | train_loss 1.570 | train_acc  0.379
# VALID 040 | valid_loss 1.620 | valid_acc  0.357
# =================================================================
# TRAIN 041 | train_loss 1.585 | train_acc  0.350
# VALID 041 | valid_loss 1.610 | valid_acc  0.373
# =================================================================
# TRAIN 042 | train_loss 1.538 | train_acc  0.379
# VALID 042 | valid_loss 1.600 | valid_acc  0.383
# =================================================================
# TRAIN 043 | train_loss 1.551 | train_acc  0.364
# VALID 043 | valid_loss 1.591 | valid_acc  0.383
# =================================================================
# TRAIN 044 | train_loss 1.529 | train_acc  0.421
# VALID 044 | valid_loss 1.580 | valid_acc  0.383
# =================================================================
# TRAIN 045 | train_loss 1.541 | train_acc  0.414
# VALID 045 | valid_loss 1.570 | valid_acc  0.400
# =================================================================
# TRAIN 046 | train_loss 1.499 | train_acc  0.393
# VALID 046 | valid_loss 1.560 | valid_acc  0.430
# =================================================================
# TRAIN 047 | train_loss 1.475 | train_acc  0.514
# VALID 047 | valid_loss 1.549 | valid_acc  0.437
# =================================================================
# TRAIN 048 | train_loss 1.479 | train_acc  0.493
# VALID 048 | valid_loss 1.538 | valid_acc  0.443
# =================================================================
# TRAIN 049 | train_loss 1.471 | train_acc  0.464
# VALID 049 | valid_loss 1.526 | valid_acc  0.463
# =================================================================
# TRAIN 050 | train_loss 1.451 | train_acc  0.464
# VALID 050 | valid_loss 1.514 | valid_acc  0.470
# =================================================================
# TRAIN 051 | train_loss 1.428 | train_acc  0.514
# VALID 051 | valid_loss 1.502 | valid_acc  0.467
# =================================================================
# TRAIN 052 | train_loss 1.407 | train_acc  0.507
# VALID 052 | valid_loss 1.489 | valid_acc  0.470
# =================================================================
# TRAIN 053 | train_loss 1.416 | train_acc  0.500
# VALID 053 | valid_loss 1.476 | valid_acc  0.473
# =================================================================
# TRAIN 054 | train_loss 1.359 | train_acc  0.500
# VALID 054 | valid_loss 1.463 | valid_acc  0.483
# =================================================================
# TRAIN 055 | train_loss 1.367 | train_acc  0.521
# VALID 055 | valid_loss 1.451 | valid_acc  0.500
# =================================================================
# TRAIN 056 | train_loss 1.368 | train_acc  0.564
# VALID 056 | valid_loss 1.439 | valid_acc  0.513
# =================================================================
# TRAIN 057 | train_loss 1.309 | train_acc  0.600
# VALID 057 | valid_loss 1.427 | valid_acc  0.537
# =================================================================
# TRAIN 058 | train_loss 1.348 | train_acc  0.593
# VALID 058 | valid_loss 1.415 | valid_acc  0.550
# =================================================================
# TRAIN 059 | train_loss 1.319 | train_acc  0.600
# VALID 059 | valid_loss 1.404 | valid_acc  0.557
# =================================================================
# TRAIN 060 | train_loss 1.237 | train_acc  0.671
# VALID 060 | valid_loss 1.393 | valid_acc  0.577
# =================================================================
# TRAIN 061 | train_loss 1.264 | train_acc  0.650
# VALID 061 | valid_loss 1.381 | valid_acc  0.587
# =================================================================
# TRAIN 062 | train_loss 1.236 | train_acc  0.650
# VALID 062 | valid_loss 1.370 | valid_acc  0.600
# =================================================================
# TRAIN 063 | train_loss 1.278 | train_acc  0.621
# VALID 063 | valid_loss 1.358 | valid_acc  0.613
# =================================================================
# TRAIN 064 | train_loss 1.241 | train_acc  0.643
# VALID 064 | valid_loss 1.345 | valid_acc  0.623
# =================================================================
# TRAIN 065 | train_loss 1.218 | train_acc  0.664
# VALID 065 | valid_loss 1.331 | valid_acc  0.627
# =================================================================
# TRAIN 066 | train_loss 1.175 | train_acc  0.707
# VALID 066 | valid_loss 1.318 | valid_acc  0.630
# =================================================================
# TRAIN 067 | train_loss 1.166 | train_acc  0.671
# VALID 067 | valid_loss 1.305 | valid_acc  0.647
# =================================================================
# TRAIN 068 | train_loss 1.190 | train_acc  0.693
# VALID 068 | valid_loss 1.292 | valid_acc  0.650
# =================================================================
# TRAIN 069 | train_loss 1.120 | train_acc  0.729
# VALID 069 | valid_loss 1.279 | valid_acc  0.657
# =================================================================
# TRAIN 070 | train_loss 1.133 | train_acc  0.736
# VALID 070 | valid_loss 1.267 | valid_acc  0.657
# =================================================================
# TRAIN 071 | train_loss 1.079 | train_acc  0.771
# VALID 071 | valid_loss 1.254 | valid_acc  0.680
# =================================================================
# TRAIN 072 | train_loss 1.112 | train_acc  0.721
# VALID 072 | valid_loss 1.242 | valid_acc  0.677
# =================================================================
# TRAIN 073 | train_loss 1.094 | train_acc  0.707
# VALID 073 | valid_loss 1.230 | valid_acc  0.687
# =================================================================
# TRAIN 074 | train_loss 1.111 | train_acc  0.721
# VALID 074 | valid_loss 1.219 | valid_acc  0.693
# =================================================================
# TRAIN 075 | train_loss 1.058 | train_acc  0.743
# VALID 075 | valid_loss 1.208 | valid_acc  0.697
# =================================================================
# TRAIN 076 | train_loss 1.027 | train_acc  0.750
# VALID 076 | valid_loss 1.199 | valid_acc  0.710
# =================================================================
# TRAIN 077 | train_loss 0.975 | train_acc  0.793
# VALID 077 | valid_loss 1.191 | valid_acc  0.733
# =================================================================
# TRAIN 078 | train_loss 1.018 | train_acc  0.786
# VALID 078 | valid_loss 1.182 | valid_acc  0.750
# =================================================================
# TRAIN 079 | train_loss 0.995 | train_acc  0.800
# VALID 079 | valid_loss 1.173 | valid_acc  0.760
# =================================================================
# TRAIN 080 | train_loss 0.985 | train_acc  0.800
# VALID 080 | valid_loss 1.162 | valid_acc  0.767
# =================================================================
# TRAIN 081 | train_loss 1.012 | train_acc  0.750
# VALID 081 | valid_loss 1.151 | valid_acc  0.770
# =================================================================
# TRAIN 082 | train_loss 0.970 | train_acc  0.807
# VALID 082 | valid_loss 1.139 | valid_acc  0.777
# =================================================================
# TRAIN 083 | train_loss 0.939 | train_acc  0.871
# VALID 083 | valid_loss 1.128 | valid_acc  0.780
# =================================================================
# TRAIN 084 | train_loss 0.972 | train_acc  0.779
# VALID 084 | valid_loss 1.117 | valid_acc  0.780
# =================================================================
# TRAIN 085 | train_loss 0.927 | train_acc  0.836
# VALID 085 | valid_loss 1.106 | valid_acc  0.787
# =================================================================
# TRAIN 086 | train_loss 0.910 | train_acc  0.843
# VALID 086 | valid_loss 1.096 | valid_acc  0.797
# =================================================================
# TRAIN 087 | train_loss 0.890 | train_acc  0.843
# VALID 087 | valid_loss 1.087 | valid_acc  0.797
# =================================================================
# TRAIN 088 | train_loss 0.912 | train_acc  0.786
# VALID 088 | valid_loss 1.077 | valid_acc  0.800
# =================================================================
# TRAIN 089 | train_loss 0.887 | train_acc  0.793
# VALID 089 | valid_loss 1.067 | valid_acc  0.800
# =================================================================
# TRAIN 090 | train_loss 0.867 | train_acc  0.829
# VALID 090 | valid_loss 1.058 | valid_acc  0.797
# =================================================================
# TRAIN 091 | train_loss 0.835 | train_acc  0.843
# VALID 091 | valid_loss 1.049 | valid_acc  0.797
# =================================================================
# TRAIN 092 | train_loss 0.807 | train_acc  0.857
# VALID 092 | valid_loss 1.041 | valid_acc  0.800
# =================================================================
# TRAIN 093 | train_loss 0.853 | train_acc  0.800
# VALID 093 | valid_loss 1.034 | valid_acc  0.803
# =================================================================
# TRAIN 094 | train_loss 0.786 | train_acc  0.879
# VALID 094 | valid_loss 1.026 | valid_acc  0.803
# =================================================================
# TRAIN 095 | train_loss 0.824 | train_acc  0.829
# VALID 095 | valid_loss 1.018 | valid_acc  0.803
# =================================================================
# TRAIN 096 | train_loss 0.831 | train_acc  0.843
# VALID 096 | valid_loss 1.012 | valid_acc  0.803
# =================================================================
# TRAIN 097 | train_loss 0.787 | train_acc  0.857
# VALID 097 | valid_loss 1.006 | valid_acc  0.803
# =================================================================
# TRAIN 098 | train_loss 0.820 | train_acc  0.821
# VALID 098 | valid_loss 1.000 | valid_acc  0.800
# =================================================================
# TRAIN 099 | train_loss 0.746 | train_acc  0.864
# VALID 099 | valid_loss 0.992 | valid_acc  0.800
# =================================================================
# TRAIN 100 | train_loss 0.771 | train_acc  0.864
# VALID 100 | valid_loss 0.985 | valid_acc  0.800
# =================================================================
# TRAIN 101 | train_loss 0.747 | train_acc  0.850
# VALID 101 | valid_loss 0.977 | valid_acc  0.800
# =================================================================
# TRAIN 102 | train_loss 0.748 | train_acc  0.843
# VALID 102 | valid_loss 0.969 | valid_acc  0.800
# =================================================================
# TRAIN 103 | train_loss 0.766 | train_acc  0.843
# VALID 103 | valid_loss 0.962 | valid_acc  0.803
# =================================================================
# TRAIN 104 | train_loss 0.776 | train_acc  0.879
# VALID 104 | valid_loss 0.955 | valid_acc  0.803
# =================================================================
# TRAIN 105 | train_loss 0.712 | train_acc  0.850
# VALID 105 | valid_loss 0.948 | valid_acc  0.803
# =================================================================
# TRAIN 106 | train_loss 0.747 | train_acc  0.836
# VALID 106 | valid_loss 0.943 | valid_acc  0.800
# =================================================================
# TRAIN 107 | train_loss 0.751 | train_acc  0.843
# VALID 107 | valid_loss 0.938 | valid_acc  0.800
# =================================================================
# TRAIN 108 | train_loss 0.763 | train_acc  0.836
# VALID 108 | valid_loss 0.934 | valid_acc  0.800
# =================================================================
# TRAIN 109 | train_loss 0.683 | train_acc  0.864
# VALID 109 | valid_loss 0.930 | valid_acc  0.800
# =================================================================
# TRAIN 110 | train_loss 0.717 | train_acc  0.879
# VALID 110 | valid_loss 0.923 | valid_acc  0.803
# =================================================================
# TRAIN 111 | train_loss 0.662 | train_acc  0.879
# VALID 111 | valid_loss 0.917 | valid_acc  0.807
# =================================================================
# TRAIN 112 | train_loss 0.676 | train_acc  0.857
# VALID 112 | valid_loss 0.909 | valid_acc  0.807
# =================================================================
# TRAIN 113 | train_loss 0.656 | train_acc  0.864
# VALID 113 | valid_loss 0.904 | valid_acc  0.803
# =================================================================
# TRAIN 114 | train_loss 0.695 | train_acc  0.871
# VALID 114 | valid_loss 0.898 | valid_acc  0.803
# =================================================================
# TRAIN 115 | train_loss 0.707 | train_acc  0.879
# VALID 115 | valid_loss 0.893 | valid_acc  0.803
# =================================================================
# TRAIN 116 | train_loss 0.664 | train_acc  0.871
# VALID 116 | valid_loss 0.888 | valid_acc  0.803
# =================================================================
# TRAIN 117 | train_loss 0.662 | train_acc  0.886
# VALID 117 | valid_loss 0.883 | valid_acc  0.803
# =================================================================
# TRAIN 118 | train_loss 0.654 | train_acc  0.864
# VALID 118 | valid_loss 0.879 | valid_acc  0.803
# =================================================================
# TRAIN 119 | train_loss 0.680 | train_acc  0.871
# VALID 119 | valid_loss 0.876 | valid_acc  0.803
# =================================================================
# TRAIN 120 | train_loss 0.663 | train_acc  0.879
# VALID 120 | valid_loss 0.871 | valid_acc  0.803
# =================================================================
# TRAIN 121 | train_loss 0.596 | train_acc  0.879
# VALID 121 | valid_loss 0.867 | valid_acc  0.803
# =================================================================
# TRAIN 122 | train_loss 0.613 | train_acc  0.871
# VALID 122 | valid_loss 0.863 | valid_acc  0.803
# =================================================================
# TRAIN 123 | train_loss 0.641 | train_acc  0.857
# VALID 123 | valid_loss 0.860 | valid_acc  0.803
# =================================================================
# TRAIN 124 | train_loss 0.632 | train_acc  0.843
# VALID 124 | valid_loss 0.855 | valid_acc  0.803
# =================================================================
# TRAIN 125 | train_loss 0.544 | train_acc  0.921
# VALID 125 | valid_loss 0.849 | valid_acc  0.803
# =================================================================
# TRAIN 126 | train_loss 0.624 | train_acc  0.864
# VALID 126 | valid_loss 0.845 | valid_acc  0.803
# =================================================================
# TRAIN 127 | train_loss 0.635 | train_acc  0.857
# VALID 127 | valid_loss 0.841 | valid_acc  0.803
# =================================================================
# TRAIN 128 | train_loss 0.618 | train_acc  0.893
# VALID 128 | valid_loss 0.837 | valid_acc  0.803
# =================================================================
# TRAIN 129 | train_loss 0.567 | train_acc  0.907
# VALID 129 | valid_loss 0.834 | valid_acc  0.803
# =================================================================
# TRAIN 130 | train_loss 0.586 | train_acc  0.907
# VALID 130 | valid_loss 0.832 | valid_acc  0.803
# =================================================================
# TRAIN 131 | train_loss 0.634 | train_acc  0.879
# VALID 131 | valid_loss 0.831 | valid_acc  0.807
# =================================================================
# TRAIN 132 | train_loss 0.572 | train_acc  0.893
# VALID 132 | valid_loss 0.830 | valid_acc  0.807
# =================================================================
# TRAIN 133 | train_loss 0.593 | train_acc  0.886
# VALID 133 | valid_loss 0.829 | valid_acc  0.803
# =================================================================
# TRAIN 134 | train_loss 0.557 | train_acc  0.907
# VALID 134 | valid_loss 0.826 | valid_acc  0.803
# =================================================================
# TRAIN 135 | train_loss 0.604 | train_acc  0.871
# VALID 135 | valid_loss 0.822 | valid_acc  0.803
# =================================================================
# TRAIN 136 | train_loss 0.554 | train_acc  0.879
# VALID 136 | valid_loss 0.816 | valid_acc  0.803
# =================================================================
# TRAIN 137 | train_loss 0.553 | train_acc  0.907
# VALID 137 | valid_loss 0.810 | valid_acc  0.807
# =================================================================
# TRAIN 138 | train_loss 0.536 | train_acc  0.871
# VALID 138 | valid_loss 0.807 | valid_acc  0.810
# =================================================================
# TRAIN 139 | train_loss 0.562 | train_acc  0.914
# VALID 139 | valid_loss 0.803 | valid_acc  0.810
# =================================================================
# TRAIN 140 | train_loss 0.612 | train_acc  0.871
# VALID 140 | valid_loss 0.800 | valid_acc  0.810
# =================================================================
# TRAIN 141 | train_loss 0.530 | train_acc  0.900
# VALID 141 | valid_loss 0.798 | valid_acc  0.813
# =================================================================
# TRAIN 142 | train_loss 0.526 | train_acc  0.907
# VALID 142 | valid_loss 0.799 | valid_acc  0.807
# =================================================================
# TRAIN 143 | train_loss 0.530 | train_acc  0.886
# VALID 143 | valid_loss 0.800 | valid_acc  0.807
# =================================================================
# TRAIN 144 | train_loss 0.568 | train_acc  0.921
# VALID 144 | valid_loss 0.799 | valid_acc  0.807
# =================================================================
# TRAIN 145 | train_loss 0.568 | train_acc  0.907
# VALID 145 | valid_loss 0.796 | valid_acc  0.807
# =================================================================
# TRAIN 146 | train_loss 0.520 | train_acc  0.907
# VALID 146 | valid_loss 0.792 | valid_acc  0.813
# =================================================================
# TRAIN 147 | train_loss 0.567 | train_acc  0.886
# VALID 147 | valid_loss 0.788 | valid_acc  0.813
# =================================================================
# TRAIN 148 | train_loss 0.562 | train_acc  0.893
# VALID 148 | valid_loss 0.786 | valid_acc  0.810
# =================================================================
# TRAIN 149 | train_loss 0.533 | train_acc  0.907
# VALID 149 | valid_loss 0.785 | valid_acc  0.813
# =================================================================
# TRAIN 150 | train_loss 0.537 | train_acc  0.900
# VALID 150 | valid_loss 0.784 | valid_acc  0.813
# =================================================================
# TRAIN 151 | train_loss 0.502 | train_acc  0.914
# VALID 151 | valid_loss 0.781 | valid_acc  0.813
# =================================================================
# TRAIN 152 | train_loss 0.509 | train_acc  0.914
# VALID 152 | valid_loss 0.777 | valid_acc  0.813
# =================================================================
# TRAIN 153 | train_loss 0.506 | train_acc  0.914
# VALID 153 | valid_loss 0.773 | valid_acc  0.817
# =================================================================
# TRAIN 154 | train_loss 0.543 | train_acc  0.907
# VALID 154 | valid_loss 0.771 | valid_acc  0.817
# =================================================================
# TRAIN 155 | train_loss 0.546 | train_acc  0.879
# VALID 155 | valid_loss 0.770 | valid_acc  0.817
# =================================================================
# TRAIN 156 | train_loss 0.455 | train_acc  0.929
# VALID 156 | valid_loss 0.770 | valid_acc  0.817
# =================================================================
# TRAIN 157 | train_loss 0.514 | train_acc  0.921
# VALID 157 | valid_loss 0.770 | valid_acc  0.813
# =================================================================
# TRAIN 158 | train_loss 0.545 | train_acc  0.893
# VALID 158 | valid_loss 0.771 | valid_acc  0.807
# =================================================================
# TRAIN 159 | train_loss 0.494 | train_acc  0.943
# VALID 159 | valid_loss 0.769 | valid_acc  0.807
# =================================================================
# TRAIN 160 | train_loss 0.488 | train_acc  0.914
# VALID 160 | valid_loss 0.767 | valid_acc  0.807
# =================================================================
# TRAIN 161 | train_loss 0.497 | train_acc  0.893
# VALID 161 | valid_loss 0.765 | valid_acc  0.807
# =================================================================
# TRAIN 162 | train_loss 0.472 | train_acc  0.921
# VALID 162 | valid_loss 0.764 | valid_acc  0.813
# =================================================================
# TRAIN 163 | train_loss 0.489 | train_acc  0.921
# VALID 163 | valid_loss 0.762 | valid_acc  0.810
# =================================================================
# TRAIN 164 | train_loss 0.509 | train_acc  0.929
# VALID 164 | valid_loss 0.761 | valid_acc  0.810
# =================================================================
# TRAIN 165 | train_loss 0.493 | train_acc  0.936
# VALID 165 | valid_loss 0.760 | valid_acc  0.813
# =================================================================
# TRAIN 166 | train_loss 0.500 | train_acc  0.929
# VALID 166 | valid_loss 0.759 | valid_acc  0.810
# =================================================================
# TRAIN 167 | train_loss 0.489 | train_acc  0.929
# VALID 167 | valid_loss 0.755 | valid_acc  0.810
# =================================================================
# TRAIN 168 | train_loss 0.470 | train_acc  0.914
# VALID 168 | valid_loss 0.751 | valid_acc  0.813
# =================================================================
# TRAIN 169 | train_loss 0.474 | train_acc  0.921
# VALID 169 | valid_loss 0.748 | valid_acc  0.813
# =================================================================
# TRAIN 170 | train_loss 0.476 | train_acc  0.900
# VALID 170 | valid_loss 0.745 | valid_acc  0.813
# =================================================================
# TRAIN 171 | train_loss 0.457 | train_acc  0.921
# VALID 171 | valid_loss 0.743 | valid_acc  0.820
# =================================================================
# TRAIN 172 | train_loss 0.482 | train_acc  0.929
# VALID 172 | valid_loss 0.743 | valid_acc  0.813
# =================================================================
# TRAIN 173 | train_loss 0.502 | train_acc  0.900
# VALID 173 | valid_loss 0.746 | valid_acc  0.810
# =================================================================
# TRAIN 174 | train_loss 0.452 | train_acc  0.900
# VALID 174 | valid_loss 0.750 | valid_acc  0.807
# =================================================================
# TRAIN 175 | train_loss 0.477 | train_acc  0.921
# VALID 175 | valid_loss 0.752 | valid_acc  0.810
# =================================================================
# TRAIN 176 | train_loss 0.473 | train_acc  0.936
# VALID 176 | valid_loss 0.753 | valid_acc  0.817
# =================================================================
# TRAIN 177 | train_loss 0.472 | train_acc  0.929
# VALID 177 | valid_loss 0.752 | valid_acc  0.817
# =================================================================
# TRAIN 178 | train_loss 0.457 | train_acc  0.921
# VALID 178 | valid_loss 0.749 | valid_acc  0.817
# =================================================================
# TRAIN 179 | train_loss 0.465 | train_acc  0.914
# VALID 179 | valid_loss 0.742 | valid_acc  0.810
# =================================================================
# TRAIN 180 | train_loss 0.468 | train_acc  0.921
# VALID 180 | valid_loss 0.735 | valid_acc  0.817
# =================================================================
# TRAIN 181 | train_loss 0.414 | train_acc  0.950
# VALID 181 | valid_loss 0.731 | valid_acc  0.820
# =================================================================
# TRAIN 182 | train_loss 0.441 | train_acc  0.936
# VALID 182 | valid_loss 0.728 | valid_acc  0.817
# =================================================================
# TRAIN 183 | train_loss 0.438 | train_acc  0.914
# VALID 183 | valid_loss 0.726 | valid_acc  0.817
# =================================================================
# TRAIN 184 | train_loss 0.467 | train_acc  0.936
# VALID 184 | valid_loss 0.726 | valid_acc  0.813
# =================================================================
# TRAIN 185 | train_loss 0.439 | train_acc  0.936
# VALID 185 | valid_loss 0.728 | valid_acc  0.813
# =================================================================
# TRAIN 186 | train_loss 0.449 | train_acc  0.943
# VALID 186 | valid_loss 0.731 | valid_acc  0.813
# =================================================================
# TRAIN 187 | train_loss 0.501 | train_acc  0.907
# VALID 187 | valid_loss 0.733 | valid_acc  0.817
# =================================================================
# TRAIN 188 | train_loss 0.430 | train_acc  0.950
# VALID 188 | valid_loss 0.734 | valid_acc  0.820
# =================================================================
# TRAIN 189 | train_loss 0.436 | train_acc  0.964
# VALID 189 | valid_loss 0.731 | valid_acc  0.823
# =================================================================
# TRAIN 190 | train_loss 0.441 | train_acc  0.929
# VALID 190 | valid_loss 0.728 | valid_acc  0.820
# =================================================================
# TRAIN 191 | train_loss 0.432 | train_acc  0.929
# VALID 191 | valid_loss 0.724 | valid_acc  0.817
# =================================================================
# TRAIN 192 | train_loss 0.405 | train_acc  0.943
# VALID 192 | valid_loss 0.720 | valid_acc  0.817
# =================================================================
# TRAIN 193 | train_loss 0.407 | train_acc  0.957
# VALID 193 | valid_loss 0.715 | valid_acc  0.817
# =================================================================
# TRAIN 194 | train_loss 0.451 | train_acc  0.936
# VALID 194 | valid_loss 0.713 | valid_acc  0.820
# =================================================================
# TRAIN 195 | train_loss 0.436 | train_acc  0.929
# VALID 195 | valid_loss 0.712 | valid_acc  0.817
# =================================================================
# TRAIN 196 | train_loss 0.413 | train_acc  0.929
# VALID 196 | valid_loss 0.711 | valid_acc  0.820
# =================================================================
# TRAIN 197 | train_loss 0.415 | train_acc  0.929
# VALID 197 | valid_loss 0.712 | valid_acc  0.820
# =================================================================
# TRAIN 198 | train_loss 0.428 | train_acc  0.921
# VALID 198 | valid_loss 0.714 | valid_acc  0.820
# =================================================================
# TRAIN 199 | train_loss 0.424 | train_acc  0.943
# VALID 199 | valid_loss 0.717 | valid_acc  0.813

# %%
trainer.test(adj, feature, label, test_idx)
# Out:
# TEST | test_loss  0.763 | test_acc   0.814
